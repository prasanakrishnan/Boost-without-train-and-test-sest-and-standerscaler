# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
import datetime

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_boston
param_grid = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

grid = GridSearchCV(XGBRegressor(), param_grid, refit = True, verbose=3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent,dependent)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   18.8s finished
# [15:31:34] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:34] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     le...
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, ...),
#              iid='warn', n_jobs=-1,
#              param_grid={'colsample_bytree': [0.7],
#                          'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7], 'min_child_weight': [4],
#                          'n_estimators': [500], 'nthread': [4],
#                          'objective': ['reg:linear'], 'silent': [1],
#                          'subsample': [0.7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'colsample_bytree': 0.7, 'learning_rate': 0.03, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 500, 'nthread': 4, 'objective': 'reg:linear', 'silent': 1, 'subsample': 0.7}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.737598      0.007361         0.029316    1.245430e-03
# 1       2.008762      0.035343         0.027317    9.423475e-04
# 2       2.234623      0.022848         0.025318    4.718762e-04
# 3       1.746258      0.008988         0.025318    1.246130e-03
# 4       1.956462      0.002493         0.024985    4.052337e-07
# 5       2.204310      0.008050         0.026983    1.413268e-03
# 6       1.758250      0.024889         0.024985    8.156588e-04
# 7       1.976449      0.003856         0.024985    4.899036e-07
# 8       1.856856      0.055840         0.026317    4.713144e-04
#
#   param_colsample_bytree param_learning_rate param_max_depth  \
# 0                    0.7                0.03               5
# 1                    0.7                0.03               6
# 2                    0.7                0.03               7
# 3                    0.7                0.05               5
# 4                    0.7                0.05               6
# 5                    0.7                0.05               7
# 6                    0.7                0.07               5
# 7                    0.7                0.07               6
# 8                    0.7                0.07               7
#
#   param_min_child_weight param_n_estimators param_nthread param_objective  \
# 0                      4                500             4      reg:linear
# 1                      4                500             4      reg:linear
# 2                      4                500             4      reg:linear
# 3                      4                500             4      reg:linear
# 4                      4                500             4      reg:linear
# 5                      4                500             4      reg:linear
# 6                      4                500             4      reg:linear
# 7                      4                500             4      reg:linear
# 8                      4                500             4      reg:linear
#
#   param_silent param_subsample  \
# 0            1             0.7
# 1            1             0.7
# 2            1             0.7
# 3            1             0.7
# 4            1             0.7
# 5            1             0.7
# 6            1             0.7
# 7            1             0.7
# 8            1             0.7
#
#                                               params  split0_test_score  \
# 0  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.846377
# 1  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.837070
# 2  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.829130
# 3  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.834085
# 4  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.825510
# 5  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.818912
# 6  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.830523
# 7  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.821931
# 8  {'colsample_bytree': 0.7, 'learning_rate': 0.0...           0.816913
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.827035           0.818117         0.830510        0.011796
# 1           0.817435           0.807610         0.820705        0.012247
# 2           0.809205           0.801314         0.813216        0.011705
# 3           0.815328           0.808628         0.819347        0.010774
# 4           0.806856           0.800554         0.810973        0.010596
# 5           0.799033           0.792819         0.803588        0.011129
# 6           0.806088           0.800736         0.812449        0.012966
# 7           0.793410           0.791447         0.802263        0.013931
# 8           0.782515           0.782881         0.794103        0.016130
#
#    rank_test_score
# 0                1
# 1                2
# 2                4
# 3                3
# 4                6
# 5                7
# 6                5
# 7                8
# 8                9

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9fc618ce5f1d> in <module>
# ----> 1 Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#       2 print("Future_Prediction={}".format(Future_Prediction))
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in predict(self, X)
#     455         """
#     456         self._check_is_fitted('predict')
# --> 457         return self.best_estimator_.predict(X)
#     458
#     459     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1073             iteration_range=iteration_range,
#    1074             output_margin=output_margin,
# -> 1075             validate_features=validate_features,
#    1076         )
#    1077
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    1995             raise TypeError('Expecting data to be a DMatrix object, got: ', type(data))
#    1996         if validate_features:
# -> 1997             self._validate_features(data)
#    1998         iteration_range = _convert_ntree_limit(self, ntree_limit, iteration_range)
#    1999         args = {
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in _validate_features(self, data)
#    2599             raise ValueError(
#    2600                 "training data did not have the following fields: " +
# -> 2601                 ", ".join(self.feature_names)
#    2602             )
#    2603         # Booster can't accept data with different feature names
#
# ValueError: training data did not have the following fields: age, bmi, children, sex_male, smoker_yes
