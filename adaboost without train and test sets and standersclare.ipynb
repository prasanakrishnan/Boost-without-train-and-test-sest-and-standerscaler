# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split




param_grid = {'n_estimators':[50,100,200,500],'learning_rate':[0.01,0.1,0.2,0.5],'loss':['linear','square','exponential'] }
grid = GridSearchCV(AdaBoostRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:   33.5s finished
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=AdaBoostRegressor(base_estimator=None, learning_rate=1.0,
#                                          loss='linear', n_estimators=50,
#                                          random_state=None),
#              iid='warn', n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2, 0.5],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 100, 200, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'learning_rate': 0.01, 'loss': 'exponential', 'n_estimators': 50}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.430734      0.004963         0.033980    7.066284e-03
# 1        0.467378      0.096352         0.036311    2.864924e-03
# 2        0.767194      0.002493         0.059963    8.156587e-04
# 3        1.894834      0.056363         0.147909    7.784051e-03
# 4        0.193547      0.001246         0.018989    2.973602e-07
# 5        0.405750      0.027346         0.033646    4.706962e-04
# 6        0.764863      0.006596         0.062629    1.884301e-03
# 7        1.917487      0.016729         0.156904    1.151142e-02
# 8        0.195546      0.002053         0.019322    4.710333e-04
# 9        0.390427      0.008374         0.032647    1.698662e-03
# 10       0.784850      0.004711         0.063962    5.095938e-03
# 11       2.284928      0.061077         0.169229    1.437497e-02
# 12       0.243517      0.045799         0.025318    6.337245e-03
# 13       0.338126      0.021625         0.024318    2.492665e-03
# 14       0.279828      0.035904         0.022986    2.158067e-03
# 15       0.342457      0.060237         0.043306    5.431308e-03
# 16       0.326801      0.054818         0.030313    8.048512e-03
# 17       0.447724      0.024818         0.039643    4.188968e-03
# 18       0.794178      0.017317         0.064960    1.413549e-03
# 19       2.026753      0.148079         0.144577    1.418933e-02
# 20       0.261506      0.037219         0.025651    6.645745e-03
# 21       0.426739      0.002448         0.034311    3.297682e-03
# 22       0.766529      0.008161         0.064626    4.187286e-03
# 23       2.207308      0.098449         0.174892    3.201134e-02
# 24       0.159902      0.003557         0.017988    1.632291e-03
# 25       0.164232      0.005903         0.019322    1.884919e-03
# 26       0.171561      0.004107         0.019656    1.884863e-03
# 27       0.199543      0.030139         0.021321    3.397370e-03
# 28       0.212203      0.006179         0.019988    8.157561e-04
# 29       0.477706      0.010224         0.036645    3.089242e-03
# 30       0.825492      0.039279         0.068624    4.024818e-03
# 31       1.453107      0.645897         0.116594    5.026451e-02
# 32       0.222197      0.017297         0.020987    1.413605e-03
# 33       0.389428      0.008214         0.034312    2.865553e-03
# 34       0.800176      0.023028         0.059630    9.415606e-04
# 35       2.095046      0.014189         0.177556    7.359069e-03
# 36       0.064626      0.009100         0.010327    9.422352e-04
# 37       0.074620      0.013267         0.011327    9.425722e-04
# 38       0.073955      0.010224         0.010660    1.246640e-03
# 39       0.078619      0.011138         0.012991    1.631317e-03
# 40       0.215202      0.014695         0.024985    7.066622e-03
# 41       0.434067      0.015186         0.035645    3.089311e-03
# 42       0.741544      0.001631         0.069957    9.268156e-03
# 43       1.899831      0.056362         0.179555    1.877319e-02
# 44       0.197878      0.010608         0.020321    1.246555e-03
# 45       0.422741      0.039126         0.036977    4.895510e-03
# 46       0.931427      0.053825         0.139914    2.020312e-02
# 47       1.896834      0.154193         0.115594    1.931511e-02
#
#    param_learning_rate   param_loss param_n_estimators  \
# 0                 0.01       linear                 50
# 1                 0.01       linear                100
# 2                 0.01       linear                200
# 3                 0.01       linear                500
# 4                 0.01       square                 50
# 5                 0.01       square                100
# 6                 0.01       square                200
# 7                 0.01       square                500
# 8                 0.01  exponential                 50
# 9                 0.01  exponential                100
# 10                0.01  exponential                200
# 11                0.01  exponential                500
# 12                 0.1       linear                 50
# 13                 0.1       linear                100
# 14                 0.1       linear                200
# 15                 0.1       linear                500
# 16                 0.1       square                 50
# 17                 0.1       square                100
# 18                 0.1       square                200
# 19                 0.1       square                500
# 20                 0.1  exponential                 50
# 21                 0.1  exponential                100
# 22                 0.1  exponential                200
# 23                 0.1  exponential                500
# 24                 0.2       linear                 50
# 25                 0.2       linear                100
# 26                 0.2       linear                200
# 27                 0.2       linear                500
# 28                 0.2       square                 50
# 29                 0.2       square                100
# 30                 0.2       square                200
# 31                 0.2       square                500
# 32                 0.2  exponential                 50
# 33                 0.2  exponential                100
# 34                 0.2  exponential                200
# 35                 0.2  exponential                500
# 36                 0.5       linear                 50
# 37                 0.5       linear                100
# 38                 0.5       linear                200
# 39                 0.5       linear                500
# 40                 0.5       square                 50
# 41                 0.5       square                100
# 42                 0.5       square                200
# 43                 0.5       square                500
# 44                 0.5  exponential                 50
# 45                 0.5  exponential                100
# 46                 0.5  exponential                200
# 47                 0.5  exponential                500
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.856595
# 1   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.852396
# 2   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.846735
# 3   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.836726
# 4   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.853640
# 5   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.849673
# 6   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.840354
# 7   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.800414
# 8   {'learning_rate': 0.01, 'loss': 'exponential',...           0.857687
# 9   {'learning_rate': 0.01, 'loss': 'exponential',...           0.854832
# 10  {'learning_rate': 0.01, 'loss': 'exponential',...           0.850226
# 11  {'learning_rate': 0.01, 'loss': 'exponential',...           0.835041
# 12  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.833958
# 13  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.833311
# 14  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.830066
# 15  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.833173
# 16  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.799803
# 17  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.716439
# 18  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.631037
# 19  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.535193
# 20  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.836881
# 21  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.804825
# 22  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.741467
# 23  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.623498
# 24  {'learning_rate': 0.2, 'loss': 'linear', 'n_es...           0.825836
# 25  {'learning_rate': 0.2, 'loss': 'linear', 'n_es...           0.830873
# 26  {'learning_rate': 0.2, 'loss': 'linear', 'n_es...           0.826118
# 27  {'learning_rate': 0.2, 'loss': 'linear', 'n_es...           0.825937
# 28  {'learning_rate': 0.2, 'loss': 'square', 'n_es...           0.712185
# 29  {'learning_rate': 0.2, 'loss': 'square', 'n_es...           0.626011
# 30  {'learning_rate': 0.2, 'loss': 'square', 'n_es...           0.556050
# 31  {'learning_rate': 0.2, 'loss': 'square', 'n_es...           0.510796
# 32  {'learning_rate': 0.2, 'loss': 'exponential', ...           0.807069
# 33  {'learning_rate': 0.2, 'loss': 'exponential', ...           0.739614
# 34  {'learning_rate': 0.2, 'loss': 'exponential', ...           0.643512
# 35  {'learning_rate': 0.2, 'loss': 'exponential', ...           0.558327
# 36  {'learning_rate': 0.5, 'loss': 'linear', 'n_es...           0.842543
# 37  {'learning_rate': 0.5, 'loss': 'linear', 'n_es...           0.831831
# 38  {'learning_rate': 0.5, 'loss': 'linear', 'n_es...           0.824681
# 39  {'learning_rate': 0.5, 'loss': 'linear', 'n_es...           0.834099
# 40  {'learning_rate': 0.5, 'loss': 'square', 'n_es...           0.595480
# 41  {'learning_rate': 0.5, 'loss': 'square', 'n_es...           0.544692
# 42  {'learning_rate': 0.5, 'loss': 'square', 'n_es...           0.500406
# 43  {'learning_rate': 0.5, 'loss': 'square', 'n_es...           0.487466
# 44  {'learning_rate': 0.5, 'loss': 'exponential', ...           0.707266
# 45  {'learning_rate': 0.5, 'loss': 'exponential', ...           0.625455
# 46  {'learning_rate': 0.5, 'loss': 'exponential', ...           0.552369
# 47  {'learning_rate': 0.5, 'loss': 'exponential', ...           0.522428
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.843793           0.832984         0.844457        0.009651
# 1            0.841496           0.835121         0.843005        0.007133
# 2            0.832109           0.833662         0.837502        0.006559
# 3            0.815159           0.825785         0.825890        0.008805
# 4            0.841259           0.834900         0.843266        0.007781
# 5            0.836310           0.836778         0.840921        0.006192
# 6            0.824000           0.831930         0.832094        0.006678
# 7            0.773777           0.794820         0.789670        0.011468
# 8            0.845060           0.834208         0.845652        0.009594
# 9            0.841596           0.836256         0.844228        0.007809
# 10           0.836107           0.834159         0.840164        0.007159
# 11           0.815776           0.826765         0.825860        0.007891
# 12           0.811266           0.829163         0.824795        0.009765
# 13           0.807486           0.823106         0.821301        0.010620
# 14           0.810027           0.823241         0.821112        0.008318
# 15           0.812533           0.826769         0.824158        0.008626
# 16           0.776865           0.791018         0.789229        0.009449
# 17           0.693026           0.720547         0.710004        0.012122
# 18           0.584082           0.597488         0.604202        0.019748
# 19           0.484523           0.535120         0.518278        0.023869
# 20           0.816342           0.824191         0.825805        0.008462
# 21           0.789775           0.799259         0.797953        0.006213
# 22           0.718942           0.738969         0.733126        0.010081
# 23           0.571689           0.617281         0.604156        0.023097
# 24           0.806379           0.826331         0.819515        0.009291
# 25           0.808769           0.824649         0.821430        0.009307
# 26           0.810095           0.821553         0.819255        0.006740
# 27           0.801351           0.816111         0.814466        0.010104
# 28           0.695312           0.712491         0.706663        0.008027
# 29           0.590220           0.600237         0.605489        0.015076
# 30           0.501204           0.539079         0.532111        0.022927
# 31           0.559006           0.481704         0.517168        0.031878
# 32           0.777498           0.801025         0.795197        0.012756
# 33           0.720125           0.745984         0.735241        0.011001
# 34           0.609576           0.649136         0.634075        0.017474
# 35           0.505825           0.555515         0.539889        0.024114
# 36           0.813928           0.827866         0.828112        0.011683
# 37           0.802487           0.827054         0.820457        0.012856
# 38           0.807246           0.829676         0.820534        0.009615
# 39           0.801224           0.825703         0.820342        0.013946
# 40           0.552351           0.571014         0.572948        0.017661
# 41           0.475823           0.526308         0.515607        0.029116
# 42           0.452172           0.487398         0.479992        0.020376
# 43           0.455977           0.472300         0.471914        0.012858
# 44           0.685830           0.703150         0.698749        0.009288
# 45           0.588315           0.614825         0.609532        0.015618
# 46           0.506561           0.554591         0.537840        0.022137
# 47           0.457470           0.532603         0.504167        0.033280
#
#     rank_test_score
# 0                 2
# 1                 5
# 2                 8
# 3                11
# 4                 4
# 5                 6
# 6                 9
# 7                27
# 8                 1
# 9                 3
# 10                7
# 11               12
# 12               14
# 13               17
# 14               18
# 15               15
# 16               28
# 17               31
# 18               37
# 19               43
# 20               13
# 21               25
# 22               30
# 23               38
# 24               22
# 25               16
# 26               23
# 27               24
# 28               32
# 29               36
# 30               42
# 31               44
# 32               26
# 33               29
# 34               34
# 35               40
# 36               10
# 37               20
# 38               19
# 39               21
# 40               39
# 41               45
# 42               47
# 43               48
# 44               33
# 45               35
# 46               41
# 47               46

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[39783.43527122]
